# %%
#!pip install pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#leia o arquivo csv, tranforme em um DataFrame e armazene em uma variável (ttn):
ttn = pd.read_csv('DEMO_PHQ.csv')

# %% [markdown]
# ## First Contact

# %%
#exibe as 5 primeiras linhas do df
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#exibe as últimas 7 linhas do df
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch           Ticket    Fare Cabin Embarked
# 884    male  25.0      0      0  SOTON/OQ 392076   7.050   NaN        S
# 885  female  39.0      0      5           382652  29.125   NaN        Q
# 886    male  27.0      0      0           211536  13.000   NaN        S
# 887  female  19.0      0      0           112053  30.000   B42        S
# 888  female   NaN      1      2       W./C. 6607  23.450   NaN        S
# 889    male  26.0      0      0           111369  30.000  C148        C
# 890    male  32.0      0      0           370376   7.750   NaN        Q

# %% [markdown]
# ## Summarization

# %%
#mostre o formato do dataset
# Out:
# (891, 12)

# %%
#crie um sumário dos dados
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#obtenha uma descrição dos dados numéricos, arredondando em duas casas decimais
# Out:
#        PassengerId  Survived  Pclass     Age   SibSp   Parch    Fare
# count       891.00    891.00  891.00  714.00  891.00  891.00  891.00
# mean        446.00      0.38    2.31   29.70    0.52    0.38   32.20
# std         257.35      0.49    0.84   14.53    1.10    0.81   49.69
# min           1.00      0.00    1.00    0.42    0.00    0.00    0.00
# 25%         223.50      0.00    2.00   20.12    0.00    0.00    7.91
# 50%         446.00      0.00    3.00   28.00    0.00    0.00   14.45
# 75%         668.50      1.00    3.00   38.00    1.00    0.00   31.00
# max         891.00      1.00    3.00   80.00    8.00    6.00  512.33

# %%
#obtenha uma descrição dos dados categóricos
# Out:
#                                      Name   Sex    Ticket    Cabin Embarked
# count                                 891   891       891      204      889
# unique                                891     2       681      147        3
# top     Birkeland, Mr. Hans Martin Monsen  male  CA. 2343  B96 B98        S
# freq                                    1   577         7        4      644

# %% [markdown]
# ## Valores nulos

# %%
#imprima um sumário dos números faltantes ou nulos
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#exclua a coluna menos relevante através do dropna passando um threshold para não excluir a coluna Age

ttn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#selecione um dataset com a condição de que todos os valores possuem valores nulos na coluna Embarked
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
#construa um filtro com o mesmo perfil das linhas faltantes baseado nas colunas Survived, Pclass, Sex, Age
#use ['Embarked'].value_counts() para entender onde a maioria desse perfil embarcou
['Embarked'].value_counts()
# Out:
# C    18
# S    14
# Name: Embarked, dtype: int64

# %%
#subistitua pelo porto mais frequente e verifique se a alteração teve efeito
#lembre=se que o fillna possui o kwarg inplace=True

ttn.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %% [markdown]
# ## Imputação

# %%
#Antes
ttn['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
# Out:
# male      124
# female     53
# Name: Sex, dtype: int64

# %%
# Out:
# 0    125
# 1     52
# Name: Survived, dtype: int64

# %%
# Out:
# médiana de idade para sobrevivente masculino:  28.0
# médiana de idade para sobrevivente feminina:  28.0
# médiana de idade para não-sobrevivente masculino:  29.0
# médiana de idade para não-sobrevivente feminina:  24.5

# %%
# Out:
# média de idade para sobrevivente masculino:  27.0
# média de idade para sobrevivente feminina:  29.0
# média de idade para não-sobrevivente masculino:  32.0
# média de idade para não-sobrevivente feminina:  25.0

# %%
#Armazenando o valor desejado em uma variável: Mediana para os sobreviventes
male_surv_median = ttn[ttn['Survived'] == 1][ttn['Sex'] == 'male']['Age'].median()
#selecionar a coluna que vai receber os valores e especificar as condições = coluna.fillna(variável)
ttn['Age'][ttn['Survived'] == 1][ttn['Sex'] == 'male'] = ttn['Age'].fillna(male_surv_median);

female_surv_median = ttn[ttn['Survived'] == 1][ttn['Sex'] == 'female']['Age'].median()
ttn['Age'][ttn['Survived'] == 1][ttn['Sex'] == 'female'] = ttn['Age'].fillna(female_surv_median);

#Armazenando o valor desejado em uma variável: Média para os não sobreviventes
male_non_surv_mean = round(ttn[ttn['Survived'] == 0][ttn['Sex'] == 'male']['Age'].mean())
ttn['Age'][ttn['Survived'] == 0][ttn['Sex'] == 'male'] = ttn['Age'].fillna(male_non_surv_mean, inplace=True);

female_non_surv_mean = round(ttn[ttn['Survived'] == 0][ttn['Sex'] == 'female']['Age'].mean())
ttn['Age'][ttn['Survived'] == 0][ttn['Sex'] == 'female'] = ttn['Age'].fillna(female_non_surv_mean, inplace=True);

# %%
#Depois
ttn['Age'].describe()
# Out:
# count    891.000000
# mean      30.156195
# std       13.034420
# min        0.420000
# 25%       22.000000
# 50%       32.000000
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# ## Agrupamentos e seleções

# %%
# Selecionar as colunas do dataset :: selecionar as colunas para agrupar :: passar as formas de agregar os valores
# Out:
#                   Age
#                   min  mean median   max
# Survived Pclass
# 0        1        2.0  41.0   38.0  71.0
#          2       16.0  33.0   32.0  70.0
#          3        1.0  28.0   31.0  74.0
# 1        1        1.0  35.0   34.0  80.0
#          2        1.0  26.0   28.0  62.0
#          3        0.0  24.0   27.0  63.0

# %%
#vamos criar faixas etárias no nossos dados  
age_cat_edges = [0, 3, 12, 18, 35, 60, 1000]
ttn['age_cat'] = pd.cut()

# %%
pd.pivot_table(ttn, values=['Survived'], 
                    index=[], columns=[],
                    aggfunc='', margins=)
# Out:
#                 Survived
# Pclass                 1      2      3  All
# Sex    age_cat
# female Babies        1.0    2.0    9.0   12
#        Children      NaN    6.0   14.0   20
#        Teen         10.0    6.0   20.0   36
#        Adult        45.0   42.0   86.0  173
#        MidAge       36.0   20.0   14.0   70
#        Senior        2.0    NaN    1.0    3
# male   Babies        1.0    8.0    9.0   18
#        Children      2.0    1.0   16.0   19
#        Teen          2.0    6.0   26.0   34
#        Adult        51.0   63.0  248.0  362
#        MidAge       54.0   27.0   44.0  125
#        Senior       12.0    3.0    4.0   19
# All                216.0  184.0  491.0  891

# %%
pd.crosstab(index=[ttn['']], columns = [ttn[''], ttn['']], 
            normalize=True).T
# Out:
# Pclass                  1         2         3
# Sex    age_cat
# female Babies    0.001122  0.002245  0.010101
#        Children  0.000000  0.006734  0.015713
#        Teen      0.011223  0.006734  0.022447
#        Adult     0.050505  0.047138  0.096521
#        MidAge    0.040404  0.022447  0.015713
#        Senior    0.002245  0.000000  0.001122
# male   Babies    0.001122  0.008979  0.010101
#        Children  0.002245  0.001122  0.017957
#        Teen      0.002245  0.006734  0.029181
#        Adult     0.057239  0.070707  0.278339
#        MidAge    0.060606  0.030303  0.049383
#        Senior    0.013468  0.003367  0.004489

# %%
fig, ax = plt.subplots(figsize=(15,8))
sns.heatmap(pd.crosstab( index= [ttn['']], 
                        columns = [ttn[''], ttn['']], normalize=True).T, 
            annot=)

# %%
fig, ax = plt.subplots(figsize=(15,8))
sns.heatmap(pd.crosstab( index= [ttn[''], ttn['']], 
                        columns = [ttn[''], ttn['']], normalize=True).T, 
            annot=) # para evitar notação científica, usar fmt='g'

# %% [markdown]
# ## Relações e distribuições

# %%
plt.clf()
XXX.hist(figsize=(10,7)) 
plt.tight_layout()
plt.show()

# %%
ttn.plot('', '', kind='', alpha=0.5)
ttn.plot('', '', kind='', alpha=0.1)

# %% [markdown]
# ## Correlações

# %%
ttn.corr().round(2)
# Out:
#              PassengerId  Survived  Pclass   Age  SibSp  Parch  Fare
# PassengerId         1.00     -0.01   -0.04  0.03  -0.06  -0.00  0.01
# Survived           -0.01      1.00   -0.34 -0.08  -0.04   0.08  0.26
# Pclass             -0.04     -0.34    1.00 -0.32   0.08   0.02 -0.55
# Age                 0.03     -0.08   -0.32  1.00  -0.23  -0.19  0.08
# SibSp              -0.06     -0.04    0.08 -0.23   1.00   0.41  0.16
# Parch              -0.00      0.08    0.02 -0.19   0.41   1.00  0.22
# Fare                0.01      0.26   -0.55  0.08   0.16   0.22  1.00

# %%
sns.heatmap(vmin=-1, vmax=1 )

# %% [markdown]
# ## PairPlot

# %%
sns_plot= sns.pairplot(ttn, hue='', diag_kind='kde')

# %%
#Para salvar a figura em png
#sns_plot.savefig("ttn_snspairplot_kde.png")

# %% [markdown]
# ## Pandas Profiling

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(df, title="Titanic Dataset", html={'style': {'full_width': True}})

# %%
profile.to_file("Titanic_Final")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Summarize dataset', max=27.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='Generate report structure', max=1.0, style=ProgressStyle(…
# HBox(children=(FloatProgress(value=0.0, description='Render HTML', max=1.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Export report to file', max=1.0, style=ProgressStyle(desc…
